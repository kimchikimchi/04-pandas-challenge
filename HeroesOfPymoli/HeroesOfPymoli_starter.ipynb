# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [raw]
# * Display the total number of players

# %%
total_players = len(purchase_data['SN'].unique())
print(total_players)
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
summary_df = pd.DataFrame([{
                            'Number of Unique Items': purchase_data['Item ID'].nunique(),
                            'Average Price': purchase_data['Price'].mean(),
                            'Number of Purchases': purchase_data["Purchase ID"].count(),
                            'Total Revenue': purchase_data["Price"].sum()
                        }])
# ToDo: Format the output?
summary_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# Group by gender first then dedup by usename
groupby_gender = purchase_data.groupby(['Gender'])
# See https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.nunique.html?highlight=nunique#pandas.core.groupby.DataFrameGroupBy.nunique
summary_df = groupby_gender['SN'].nunique()
summary_df.head()
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: SN, dtype: int64

# %%
all_players_count = gender_summary_df.sum()
female_players_count = gender_summary_df.loc['Female']
male_players_count = gender_summary_df.loc['Male']
other_players_count = gender_summary_df.loc['Other / Non-Disclosed']

female_players_percent = female_players_count / all_players_count * 100
male_players_percent = male_players_count / all_players_count * 100
other_players_percent = other_players_count / all_players_count * 100

summary_df = pd.DataFrame([
                {'Gender': 'Male', 'Total Count': male_players_count, 'Percentage of Players': male_players_percent},
                {'Gender': 'Female', 'Total Count': female_players_count, 'Percentage of Players': female_players_percent},
                {'Gender': 'Other', 'Total Count': other_players_count, 'Percentage of Players': other_players_percent}
            ])
# ToDo: Reformat
summary_df
# Out:
#    Gender  Total Count  Percentage of Players
# 0    Male          484              84.027778
# 1  Female           81              14.062500
# 2   Other           11               1.909722

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
groupby_gender = purchase_data.groupby(['Gender'])
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 15            15      Lisassa64   21                 Female       98
# 18            18      Reunasu60   22                 Female       82
# 22            22   Siarithria38   38  Other / Non-Disclosed       24
# 38            38       Reulae52   10                 Female      116
# 41            41      Assosia88   20                 Female        7
# 55            55      Phaelap26   25                 Female       84
# 82            82     Haerithp41   16  Other / Non-Disclosed      160
# ...

# %%
count_df = groupby_gender['Purchase ID'].count()
mean_df = groupby_gender['Price'].mean()
sum_df = groupby_gender['Price'].sum()

# Create a summary dataframe initialized with series data returned above
summary_df = pd.DataFrame({
                            'Purchase Count': count_df,
                            'Average Purchase Price': mean_df,
                            'Total Purchase Value': sum_df
                          })

# Use the player counts per gender from above.
total_purchase_person = [
                            sum_df['Female'] / female_players_count,
                            sum_df['Male'] / male_players_count,
                            sum_df['Other / Non-Disclosed'] / other_players_count
                        ]
summary_df['Avg Total Purchase per Person'] = total_purchase_person
# ToDo: Format
summary_df
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Gender
# Female                               361.94                       4.468395
# Male                                1967.64                       4.065372
# Other / Non-Disclosed                 50.19                       4.562727

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Assuming no human lives more than 200 yrs as the upper bound
bins = [0, 9, 14, 19, 24, 29, 34, 39, 200]
labels = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']

purchase_data['Age Group'] = pd.cut(purchase_data['Age'], bins, labels=labels)
groupby_agegroup = purchase_data.groupby(['Age Group'])

# Get the series of unique player count
total_players_byagegroup = groupby_agegroup['SN'].nunique()
summary_df = pd.DataFrame({"Total Count": total_players_byagegroup })
summary_df['Percentage of Players'] = summary_df['Total Count'] / summary_df['Total Count'].sum() * 100

# Todo: Formatting.
summary_df
# Out:
#            Total Count  Percentage of Players
# Age Group
# <10                 17               2.951389
# 10-14               22               3.819444
# 15-19              107              18.576389
# 20-24              258              44.791667
# 25-29               77              13.368056
# 30-34               52               9.027778
# 35-39               31               5.381944
# 40+                 12               2.083333

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
summary_df = pd.DataFrame({
                            'Purchase Count': groupby_agegroup['Purchase ID'].count(),
                            'Average Purchase Price': groupby_agegroup['Price'].mean(),
                            'Total Purchase Value': groupby_agegroup['Price'].sum(),
                        })

summary_df['Avg Total Purchase per Person'] = summary_df['Total Purchase Value'] / total_players_byagegroup

# ToDo: Formatting
summary_df
# Out:
#            Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Group
# <10                    23                3.353478                 77.13
# 10-14                  28                2.956429                 82.78
# 15-19                 136                3.035956                412.89
# 20-24                 365                3.052219               1114.06
# 25-29                 101                2.900990                293.00
# 30-34                  73                2.931507                214.00
# 35-39                  41                3.601707                147.67
# 40+                    13                2.941538                 38.24
#
#            Avg Total Purchase per Person
# Age Group
# <10                             4.537059
# 10-14                           3.762727
# 15-19                           3.858785
# 20-24                           4.318062
# 25-29                           3.805195
# 30-34                           4.115385
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
groupby_player = purchase_data.groupby(['SN'])

summary_df = pd.DataFrame({
                            'Purchase Count': groupby_player['Purchase ID'].count(),
                            'Average Purchase Price': groupby_player['Price'].mean(),
                            'Total Purchase Price': groupby_player['Price'].sum()
            })
summary_df = summary_df.sort_values('Total Purchase Price', ascending=False)
# ToDo: Formatting
summary_df.head()
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Price
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
groupby_items = purchase_data.groupby(['Item ID', 'Item Name'])

summary_df = pd.DataFrame({
                            'Purchase Count': groupby_items['Purchase ID'].count(),
                            'Item Price': groupby_items['Price'].mean(),
                            'Total Purchase Value': groupby_items['Price'].sum()
                        })
summary_df = summary_df.sort_values('Purchase Count', ascending=False)
# ToDo: Formatting
summary_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 145     Fiery Glass Crusader                            4.580000
# 132     Persuasion                                      3.221111
# 108     Extraction, Quickblade Of Trembling Hands       3.530000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
summary_df = summary_df.sort_values('Total Purchase Value', ascending=False)
summary_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 82      Nirvana                                         4.900000
# 145     Fiery Glass Crusader                            4.580000
# 103     Singed Scalpel                                  4.350000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...
